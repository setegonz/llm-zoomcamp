# %% [markdown]
# # Question 1: Context Engineering
#
# Try the following experiment:
#
#     Open ChatGPT in a private browser window: https://chatgpt.com
#     Enter this prompt: "Create a Kestra flow that loads NYC taxi data from CSV to BigQuery"
#     Then, use Kestra's AI Copilot with the same prompt
#
# After trying the same prompt in ChatGPT vs Kestra's AI Copilot, what is the primary reason AI Copilot generates better Kestra flows?
#
# ## Answer:
#
#     AI Copilot has access to current Kestra plugin documentation

# %% [markdown]
# # Question 2: RAG vs No RAG
#
# Run both 1_chat_without_rag.yaml and 2_chat_with_rag.yaml in the Kestra UI. Read the execution logs for each.
#
# The non-RAG response about Kestra 1.1 features is best described as:
# ## Answer:
#     Vague, generic, or fabricated — the model guesses from training data

# %% [markdown]
# INFO 2026-07-01T17:15:56.032747Z ❌ Response WITHOUT RAG (no retrieved context):
# Kestra 1.1 introduced several exciting features, significantly enhancing its capabilities. Here are 5 major features with brief descriptions:
#
# 1.  **Worker Groups:** This feature allows users to organize their workers into distinct groups. Tasks can then be explicitly assigned to run on specific worker groups. This is crucial for:
#     *   **Resource Isolation:** Dedicating certain workers for resource-intensive tasks (e.g., Spark jobs) while others handle lighter workloads.
#     *   **Environment Specificity:** Having workers with specific software installations or network access for particular types of tasks (e.g., Python 3.9 workers vs. Python 3.10 workers, or workers with database access).
#     *   **Scalability & Resilience:** Better managing and scaling specific parts of your workflow infrastructure.
#
# 2.  **Plugin System Revamp & Enhanced Documentation:** While not a single feature, this encompasses significant improvements to how plugins are managed and documented.
#     *   **Easier Plugin Development & Installation:** Streamlined processes for creating and adding new plugins.
#     *   **Auto-generated & Integrated Documentation:** The Kestra UI now features significantly better, auto-generated documentation for all plugins (core and custom). This makes it much easier for users to discover and understand the available tasks, their configurations, and their usage directly within Kestra.
#
# 3.  **Namespace-Based Flow/Task Permissions (ACLs):** Kestra 1.1 introduced more granular access control, allowing administrators to define permissions based on namespaces.
#     *   **Role-Based Access Control:** Users or groups can be granted specific roles (e.g., `viewer`, `editor`, `admin`) for particular namespaces.
#     *   **Secure Multi-Tenancy:** Enables organizations to securely onboard multiple teams or departments, each managing their flows within their own namespaces without interfering with or accessing others' data.
#
# 4.  **Integrated Flow Editor (Monaco Editor):** The Kestra UI now incorporates the powerful Monaco Editor (the same editor powering VS Code) for creating and editing flows.
#     *   **Syntax Highlighting:** Improved readability and error detection.
#     *   **Autocompletion:** Speeds up flow development by suggesting available tasks, properties, and values.
#     *   **YAML Validation:** Provides real-time feedback on syntax errors, helping users write valid Kestra flows more efficiently.
#
# 5.  **Blueprint Marketplace:** Kestra 1.1 launched an integrated marketplace for "Blueprints."
#     *   **Reusable Flow Templates:** Blueprints are pre-built, shareable Kestra flows designed for common use cases.
#     *   **Accelerated Development:** Users can browse, import, and adapt these blueprints, significantly reducing the time and effort required to set up new workflows.
#     *   **Community Sharing:** Fosters a community where users can contribute and share their own useful flow patterns.
#
# 🤔 Did you notice that this response seems to be:
# - Incorrect?
# - Vague/generic?
# - Listing features that haven't been added in exactly this version but rather a long time ago?
#
# 👉 This is why context matters! Run `2_chat_with_rag.yaml` to see the accurate, context-grounded response.

# %% [markdown]
# INFO 2026-07-01T17:22:59.267669Z ✅ RAG Response (with retrieved context):
# Kestra 1.1 introduced several major features. Here are at least 5 of them with brief descriptions:
#
# 1.  **New Filters**: The UI filters were completely redesigned to be more intuitive and powerful. Users can now choose from explicit filter options, reset filters with a single click, save frequently used combinations, and customize table columns.
# 2.  **No-Code Dashboard Editor**: Kestra 1.1 extended the no-code multi-panel editor to custom dashboards, allowing users to build and customize dashboards directly from the UI without writing YAML.
# 3.  **Multi-Agent AI Systems**: AI agents in Kestra can now use other AI agents as tools, enabling sophisticated multi-agent orchestration workflows where a primary agent can delegate subtasks to specialized expert agents.
# 4.  **Fix with AI**: When task runs fail, Kestra 1.1 provides AI-powered suggestions to help users quickly diagnose and resolve issues, offering intelligent recommendations for fixes.
# 5.  **Human Task (Enterprise Edition)**: This new feature allows Enterprise Edition users to add manual approval steps to workflows. Executions pause at a `HumanTask` until designated users or group members approve and resume them, enabling human-in-the-loop workflows.
# 6.  **Improved Air-Gapped Support**: Kestra 1.1 significantly improved support for offline and air-gapped environments by adapting the UI to run without internet connectivity, ensuring full functionality in isolated setups.
# 7.  **Dozens of New Plugins**: The release included a large number of new community-contributed plugins, expanding integrations across various categories such as Data & Database (Liquibase, dlt), SaaS & API (Airtable, Stripe, Shopify), Cloud & Infrastructure (Dataform, AWS CloudWatch), AI Model Providers (Oracle Cloud Infrastructure GenAI, Cloudflare Workers AI, LocalAI), and many more.
#
# 🎉 Note that this response is detailed, accurate, and grounded in the actual release documentation. Compare this with the output from 1_chat_without_rag.yaml!

# %% [markdown]
# # Question 3: Token usage — short summary
#
# Run 4_simple_agent.yaml with summary_length = short (leave the other inputs as defaults).
#
# Open the execution logs and find the token usage logged by the log_token_usage task.
#
# What is the approximate output token count for multilingual_agent?
# ## Answer: 60-100 tokens

# %% [markdown]
# 2026-07-01 14:28:17.213
#
# 📊 Token Usage Summary:
#
# Multilingual Agent:
# - Input tokens: 282
# - Output tokens: 76
# - Total tokens: 358
#
# English Brevity Agent:
# - Input tokens: 91
# - Output tokens: 38
# - Total tokens: 129
#
# 💡 Tip: Monitor token usage to understand costs and optimize prompts!

# %% [markdown]
# # Question 4
#  Run 4_simple_agent.yaml again with summary_length = long.
#
# Compare the multilingual_agent output token count to your result from Question 3. Roughly how many times more output tokens does the long summary use?
# ## Answer:
#     2-5x more

# %% [markdown]
# 2026-07-01 14:31:45.149
#
# 📊 Token Usage Summary:
#
# Multilingual Agent:
# - Input tokens: 282
# - Output tokens: 197
# - Total tokens: 479
#
# English Brevity Agent:
# - Input tokens: 212
# - Output tokens: 53
# - Total tokens: 265
#
# 💡 Tip: Monitor token usage to understand costs and optimize prompts!

# %% [markdown]
# # Question 5: Modifying a flow
#
# Open 4_simple_agent.yaml in the Kestra flow editor. Find the english_brevity task and change its prompt from asking for exactly 1 sentence to asking for exactly 3 sentences.
#
# Save the flow, then run it with summary_length = long.
#
# ## Answer: Compare the english_brevity output token count to the original 1-sentence version (also with summary_length = long). How do they compare?
#
#     About the same (within 20%)
#     2-4x more
#     5-10x more
#     10x+ more

# %% [markdown]
# INFO 2026-07-01T17:39:20.899888Z 📊 Token Usage Summary:
#
# Multilingual Agent:
# - Input tokens: 282
# - Output tokens: 185
# - Total tokens: 467
#
# English Brevity Agent:
# - Input tokens: 200
# - Output tokens: 81
# - Total tokens: 281
#
# 💡 Tip: Monitor token usage to understand costs and optimize prompts!

# %% [markdown]
# Question 6: Best Practices
#
# Based on what you learned in this module, for production workflows requiring deterministic, repeatable results with strict compliance requirements (e.g., financial reporting, workflows in highly regulated industries), which approach is most appropriate?
# ## Answer
#     Use traditional task-based workflows for predictability and auditability
